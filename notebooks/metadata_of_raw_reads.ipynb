# %% [markdown]
# # The metadata of raw reads downloaded from the source

# %%
import pandas as pd

# %%
# Show current working directory
# !pwd
# Out:
# /mnt/d/projects/solanum_lycopersicum/notebooks

# %%
# Read in dataset with pandas module
meta = pd.read_csv("../data/01_raw/SraRunTable.txt")
meta
# Out:
#            Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 0  SRR10851992      OTHER          76  7266228520  PRJNA599965  SAMN13763298
# 1  SRR10851993      OTHER          76  8793988576  PRJNA599965  SAMN13763297
# 2  SRR10851994      OTHER          76  6808701756  PRJNA599965  SAMN13763296
# 3  SRR10851995      OTHER          76  8061034544  PRJNA599965  SAMN13763295
# 4  SRR10851996    RNA-Seq          76  8124663340  PRJNA599965  SAMN13763294
# 5  SRR10851997    RNA-Seq          76  9357564144  PRJNA599965  SAMN13763293
#
#         Bytes Center Name Consent DATASTORE filetype  ... LibrarySelection  \
# 0  2736172900         GEO  public          fastq,sra  ...            other
# 1  3355806396         GEO  public          fastq,sra  ...            other
# 2  2604827967         GEO  public          fastq,sra  ...            other
# 3  3087813097         GEO  public          fastq,sra  ...            other
# ...

# %%
# List all the column names
for f in meta.columns:
    print(f)
# Out:
# Run
# Assay Type
# AvgSpotLen
# Bases
# BioProject
# BioSample
# Bytes
# Center Name
# Consent
# DATASTORE filetype
# DATASTORE provider
# DATASTORE region
# Experiment
# GEO_Accession (exp)
# Instrument
# LibraryLayout
# LibrarySelection
# LibrarySource
# Organism
# Platform
# ReleaseDate
# Sample Name
# source_name
# SRA Study
# tissue
# treatment

# %%
# Convert bytes into giga-bytes
meta['Gb'] = meta['Bytes'].astype('int64') / (1024**3)
# Show columns I am interested in
meta[["Run", "Gb", "Assay Type", "source_name", "tissue", "treatment"]]
# Out:
#            Run        Gb Assay Type  \
# 0  SRR10851992  2.548260      OTHER
# 1  SRR10851993  3.125338      OTHER
# 2  SRR10851994  2.425935      OTHER
# 3  SRR10851995  2.875750      OTHER
# 4  SRR10851996  2.886109    RNA-Seq
# 5  SRR10851997  3.080320    RNA-Seq
#
#                                          source_name                 tissue  \
# 0  ribosome protected fragments from LTM-treated ...  Three-week-old leaves
# 1  ribosome protected fragments from LTM-treated ...  Three-week-old leaves
# 2  ribosome protected fragments from CHX-treated ...  Three-week-old leaves
# 3  ribosome protected fragments from CHX-treated ...  Three-week-old leaves
# 4                              total RNA from leaves  Three-week-old leaves
# 5                              total RNA from leaves  Three-week-old leaves
#
#   treatment
# 0       LTM
# 1       LTM
# 2       CHX
# 3       CHX
# 4       NaN
# 5       NaN
